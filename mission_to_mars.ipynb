# %%
# Dependencies
from bs4 import BeautifulSoup as bs
import pandas as pd
import requests as res
import selenium
from splinter import Browser

# %%
# URL of page to be scraped
url = 'https://mars.nasa.gov/news/'

# %%
# Retrieve page with the requests module
response = res.get(url)

# %%
# Create BeautifulSoup object; parse with 'html.parser'
soup = bs(response.text, 'html.parser')

# %%
# Examine the results, then determine element that contains sought info
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <!-- Always force latest IE rendering engine or request Chrome Frame -->
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"5e33925808","applicationID":"59562082","transactionName":"JVcPR0MLWApSRU1eAQVVEhxSC1oSUlkWbBMHXwRAHhdcCUA=","queueTime":0,"applicationTime":187,"agent":""}
#   </script>
#   <script type="text/javascript">
# ...

# %%
# Examine the results, then determine element that contains sought info
# results are returned as an iterable list
results = soup.find_all('div', class_='slide')
results
# Out:
# [<div class="slide">
#  <div class="image_and_description_container">
#  <a href="/news/8426/nasa-garners-7-webby-award-nominations/">
#  <div class="rollover_description">
#  <div class="rollover_description_inner">
#  Nominees include four JPL projects: the solar system and climate websites, InSight social media, and a 360-degree Earth video. Public voting closes April 18, 2019.
#  </div>
#  <div class="overlay_arrow">
#  <img alt="More" src="/assets/overlay-arrow.png"/>
#  </div>
#  </div>
#  <img alt="NASA Garners 7 Webby Award Nominations" class="img-lazy" data-lazy="/system/news_items/list_view_images/8426_Webby2019-320x240.jpg" src="/assets/loading_320x240.png"/>
#  </a>
#  </div>
#  <div class="content_title">
#  <a href="/news/8426/nasa-garners-7-webby-award-nominations/">
#  NASA Garners 7 Webby Award Nominations
#  </a>
#  </div>
#  </div>, <div class="slide">
#  <div class="image_and_description_container">
# ...

# %%
# Loop through returned results
for result in results:
    # Error handling
    try:
        # Identify and return title of listing
        title = result.find('div', class_="content_title").text
        para = result.find('div', class_="rollover_description_inner").text
        # Identify and return price of listing
        #price = result.a.span.text
        # Identify and return link to listing
        #link = result.a['href']

        # Print results only if title, price, and link are available
        if (title and para):
            print('-------------')
            print("News_Title:", title)
            print("News_Paragrapgh:", para)
            
    except AttributeError as e:
        print(e)
# Out:
# -------------
# News_Title:
#
# NASA Garners 7 Webby Award Nominations
#
#
# News_Paragrapgh:
# Nominees include four JPL projects: the solar system and climate websites, InSight social media, and a 360-degree Earth video. Public voting closes April 18, 2019.
#
# -------------
# News_Title:
#
# NASA's Opportunity Rover Mission on Mars Comes to End
#
#
# News_Paragrapgh:
# NASA's Opportunity Mars rover mission is complete after 15 years on Mars. Opportunity's record-breaking exploration laid the groundwork for future missions to the Red Planet.
#
# -------------
# News_Title:
#
# NASA's InSight Places First Instrument on Mars
#
#
# News_Paragrapgh:
# In deploying its first instrument onto the surface of Mars, the lander completes a major mission milestone.
#
# -------------
# News_Title:
#
# NASA Announces Landing Site for Mars 2020 Rover
#
#
# News_Paragrapgh:
# After a five-year search, NASA has chosen Jezero Crater as the landing site for its upcoming Mars 2020 rover mission.
#
# ...

# %%
# using splinter to open the mars image page
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
url_2 = 'https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars'

# %%
# divs = browser.find_by_tag('a')
# print('divs')

# %%
# browser.click_link_by_partial_text('category')

# %%
#first_found = browser.find_by_id('full_image').first.click()

# %%
# for x in range(1, 6):

# html = browser.html
# soup = bs(html, 'html.parser')
response_2 = res.get(url_2)
soup_2 = bs(response_2.text, 'html.parser')
quotes = soup_2.find_all('a', class_='fancybox')
quotes

#    for quote in soup_2.find_all('a', class_='fancybox'):
#     print(quote.get('href')) 
        
#         print('page:', x, '-------------')
#         print(quote.text)

#     browser.click_link_by_partial_text('Next')
# Out:
# [<a class="button fancybox" data-description="Galaxy NGC 1068 is shown in visible light and X-rays in this composite image. High-energy X-rays (magenta) captured by NASA's NuSTAR, are overlaid on visible-light images from both NASA's Hubble Space Telescope and the Sloan Digital Sky Survey." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/mediumsize/PIA20057_ip.jpg" data-link="/spaceimages/details.php?id=PIA20057" data-title="NuSTAR's View of Galaxy NGC 1068" id="full_image">
#  					FULL IMAGE
#  				  </a>,
#  <a class="fancybox" data-description="This is NASA InSights second full selfie on Mars. Since taking its first selfie, a thin coating of dust now covers the spacecraft." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23203_hires.jpg" data-link="/spaceimages/details.php?id=PIA23203" data-thumbnail="/spaceimages/images/wallpaper/PIA23203-640x350.jpg" data-title="InSight" dusty="" s="" selfie'="">
# ...

# %%
for quote in quotes:
    #print(quote.find(['href']))
    #quote.find(attrs={'data-fancybox-href'})
    print('https://'+ quote['data-fancybox-href'])
# Out:
# https:///spaceimages/images/mediumsize/PIA20057_ip.jpg
# https:///spaceimages/images/largesize/PIA23203_hires.jpg
# https:///spaceimages/images/largesize/PIA23191_hires.jpg
# https:///spaceimages/images/largesize/PIA23202_hires.jpg
# https:///spaceimages/images/largesize/PIA23201_hires.jpg
# https:///spaceimages/images/largesize/PIA23180_hires.jpg
# https:///spaceimages/images/largesize/PIA23189_hires.jpg
# https:///spaceimages/images/largesize/PIA23188_hires.jpg
# https:///spaceimages/images/largesize/PIA23187_hires.jpg
# https:///spaceimages/images/largesize/PIA23178_hires.jpg
# https:///spaceimages/images/largesize/PIA23186_hires.jpg
# https:///spaceimages/images/largesize/PIA23177_hires.jpg
# https:///spaceimages/images/largesize/PIA23176_hires.jpg
# https:///spaceimages/images/largesize/PIA23120_hires.jpg
# https:///spaceimages/images/largesize/PIA23119_hires.jpg
# https:///spaceimages/images/largesize/PIA23116_hires.jpg
# ...

# %%
# for quote in quotes:
#     img= quotes.get('href')
#     print(img)

# %%
inputTag = soup.findAll(attrs={"name" : "stainfo"})
